# %% [markdown]
# # Week 01

# %%
# this is python
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# # Guessing Game

# %%
# guessing game
from random import randint
from IPython.display import clear_output

guessed = False
number = randint(0,100)
guesses = 0

while not guessed:
    ans = input("Try to guess the number I am thinking of!")
    # use tab to indent
    guesses += 1
    clear_output()
    if int(ans) == number:
        print("Congrats! You guessed it correctly.")
        # use tab twice to indent twice
        print("It took you {} guesses!". format(guesses))
        break
    elif int(ans) > number:
        print("The number is lower than you guessed.")
    elif int(ans) < number:
        print("The number is greater than you guessed.")
# Out:
# Congrats! You guessed it correctly.
# It took you 8 guesses!

# %%
print("{} is my favourite sport".format(element))
element = "Football"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print("{} is my favourite sport".format(element))
#       2 element = "Football"
#
# NameError: name 'element' is not defined
