# %% [markdown]
# # User input and type converting

# %%
# accepting and outputting user input
print(input("What is your name?"))
# Out:
# Aaron

# %%
# saving what the user inputs
ans = input("What is your name?")
print("Hello {}!".format(ans))
# Out:
# Hello Aaron!

# %%
# how to check the data type of a variable
num = 5
print(type(num))
# Out:
# <class 'int'>

# %%
# converting a variable from one data type to another
num = '9'
num = int(num) # re-declaring num to store an integer
print(type(num)) # checking type to make sure conversion worked
# Out:
# <class 'int'>

# %%
# working with user input to perform calculations
ans = input("Type a number to add: ")
print(type(ans)) # default type is string, must convert
result = 100 + int(ans)
print("100 + {} = {}".format(ans,result))
# Out:
# <class 'str'>
# 100 + 17 = 117

# %%
# using the try and accept blocks, use tab to indent where necessary
try:
    ans = float(input("Type a number to add:"))
    print("100 + {} = {}".format(ans,100+ans))
except:
    print("You did not put in a valid number!")
# If we didn’t have the try and except in place, the program would break, and the last print statement wouldn’t occur.
print("The program did not break!")
# Out:
# 100 + 17.7 = 117.7
# The program did not break!

# %% [markdown]
# # Monday exercises

# %%
string1 = "True"
string1 = bool(string1)
print(type(string1))
# Out:
# <class 'bool'>

# %%
num1 = int(input("Pick a number:"))
num2 = int(input("Pick another number:"))
sum = num1 + num2
print(sum)
# Out:
# 17

# %%
year = input("What year was your car made?")
make = input("What is the make of your car?")
model = input("What is the model of your car?")
colour = input("What is the colour of your car?")
print("Your car was made in {} by {}. Its model is {} and it is the colour {}!".format(year,make,model,colour.lower()))
# Out:
# Your car was made in 2014 by Holden. Its model is Equipe and it is the colour white!

# %% [markdown]
# # IF statements

# %%
# using an if statement to only run code if the condition is met
x, y = 5, 10
if x < y:
    print("x is less than y")
# Out:
# x is less than y

# %%
# checking user input
ans = int(input("What is 5 +5?"))
if ans == 10:
    print("You got it right!")
# Out:
# You got it right!

# %%
# using the keyword "and" in an "if statement"
x,y,z = 5,10,5
if x < y and x == z:
    print("Both statements were true")
# Out:
# Both statements were true

# %%
# using the keyword "or" in an "if statement"
x,y,z = 5,10,5
if x < y or x != z:
    print("One or both statements were true")
# Out:
# One or both statements were true

# %%
# using the keyword 'not' within an 'if statement'
flag = False
if not flag:        # same as saying if not true
    print("Flag is false")
# Out:
# Flag is false

# %%
# using the keyword "in" within an "if statement"
word = "Baseball"
if "b" in word:
    print("{} contains the character b".format(word))
# Out:
# Baseball contains the character b

# %%
# using the keyword " not in" within an "if statement"
word = "Baseball"
if "x" not in word:
    print("{} does not contain the character x".format(word))
# Out:
# Baseball does not contain the character x

# %% [markdown]
# # Tuesday exercises

# %%
ans = input("Write anything")
if "es" in ans:
    print("{} contains the characters 'es'".format(ans))
else:
    print("{} does not contain 'es'".format(ans))
# Out:
# see does not contain 'es'

# %%
ans = input("Write anything")
if ans[-3:] == "ing":
    print("{} ends in the characters 'ing'".format(ans))
else:
    print("{} does not end in the characters 'ing'.".format(ans))
# Out:
# Smiling ends in the characters 'ing'

# %%
word = "Waiting"
print(word[-3:])
# Out:
# ing

# %%
ans1 = input("Write anything").lower()
ans2 = input("Write anything again").lower()
if ans1 == ans2:
    print("{} and {} are the same!".format(ans1,ans2))
else:
    print("{} and {} are not the same!".format(ans1,ans2))
# Out:
# aaron and aaron are the same!

# %%
ans1 = input("Write anything")
ans2 = input("Write anything again")
if ans1.lower() == ans2.lower():
    print("{} and {} are the same!".format(ans1,ans2))
else:
    print("{} and {} are not the same!".format(ans1,ans2))
# Out:
# Aaron and aaron are the same!

# %%
num1 = int(input("Write a number"))
if num1 < 10:
    print(num1*num1)
else:
    print("{} is equal to or higher than 10".format(num1))
# Out:
# 64

# %% [markdown]
# # Elif statements

# %%
# using the elif conditional statement
x,y = 5,10
if x > y:
    print("x is greater")
elif x < y:
    print("y is greater")
# Out:
# y is greater

# %%
# checking more than one elif conditional statement
x,y = 5,10
if x > y:
    print('x is greater')
elif (x+10) < y:        # checking if 15 is less than 10. Within the conditional, we perform addition, but we wrap it within parenthesis so that it executes the math operation first.
    print('x is less')
elif (x+5) == y:        # checking if 10 is equal to 10
    print("Equal")
# Out:
# Equal

# %%
# writing multiple conditionals within each other - multiple block levels
x,y,z = 5,10,5
if x > y:
    print("Greater")
elif x <= y:
    if x == z:
        print("x is equal to z")        # resulting output
    elif x != z:
        print("x is not equal to z")    # won't get hit
# Out:
# x is equal to z

# %%
# testing output of two if statements in a row that are both true
x,y,z = 5,10,5
if x < y:
    print("x is less")
elif x == z:
    print("X is qual to z")
# Out:
# x is less

# %% [markdown]
# # Wednesday exercises

# %%
num1 = int(input("Write a number"))
if num1 > 100:
    print("{} is more than 100".format(num1))
elif num1 < 100:
    print("{} is less than 100".format(num1))
# Out:
# 116 is more than 100

# %%
# fix this code
x,y = 5,10
if x > y:
    print("greater")
elif x < y:
    print("lower")
# Out:
# lower

# %% [markdown]
# # Else statements

# %%
# using an else statement
name = "John"
if name == "Jacob":
    print("Hello Jacob!")
else:
    print("Hello, your name is not Jacob!")
# Out:
# Hello, your name is not Jacob!

# %%
# writing a full conditional statement with if, elif and else
name = "John"
if name[0] == "A":
    print("Name starts with an A")
elif name[0] == "B":
    print("Name starts with a B")
elif name[0] == "J":
    print("Name starts with a J")
else:                                               # covers all other possibilities
    print("Name starts with a {}".format(name[0]))
# Out:
# Name starts with a J

# %% [markdown]
# # Thursday exercises

# %%
# fix the code
name = "John"
if name == "Jack":
    print("Hello Jack")
elif name == "John":
    print("Hello John")
# Out:
# Hello John

# %%
time = int(input("Write the time of day in military time e.g. 11 PM equals 2300"))
if time < 1200:
    print("Good morning")
elif time >= 1700:
    print("Good evening")
else:
    print("Good afternoon")
# Out:
# Good evening

# %% [markdown]
# # Friday project: creating a calculator

# %%
# step 1: ask user for calculation type to be performed
operation = input("Woudl you like to add/subtract/multiply/divide?").lower()
print("You chose {}.".format(operation))    # for testing purposes
# Out:
# You chose divide.

# %%
# step 2: ask for numbers, alert order matters for subtracting and dividing
if operation == "subtract" or operation == "divide":
    print("You chose {}.".format(operation))
    print("Please keep in mind that the order of your numbers matter.")
num1 = input("What is the first number?")
num2 = input("What is the second number?")
print("First number: {}".format(num1))  # for testing purposes
print("Second number: {}".format(num2)) # for testing purposes
# Out:
# You chose divide.
# Please keep in mind that the order of your numbers matter.
# First number: 17
# Second number: 6

# %%
# step 3: setup try/except for mathematical operation
try:
    #step 3a: immediately try to convert numbers input to float
    num1,num2 = float(num1),float(num2)
    # step 3b: perform operation and print result
    if operation == "add":
        result = num1 + num2
        print("{} + {} = {}".format(num1,num2,result))
    elif operation == "subtract":
        result = num1 - num2
        print("{} - {} = {}".format(num1,num2,result))
    elif operation == 'multiply':
        result = num1 * num2
        print("{} * {} = {}".format(num1,num2,result))
    elif operation == "divide":
        result = num1 / num2
        print("{} / {} = {}".format(num1,num2,result))
    else:
        # else will hit if they didn't chose an option correctly
        print("Sorry, but '{}' is not an option.".format(operation))
except:
    # step 3c: print error
    print("Error: Improper numbers used. Please try again.")
# Out:
# 17.0 / 6.0 = 2.8333333333333335

# %%
# step 1: ask user for calculation type to be performed
operation = input("Woudl you like to add/subtract/multiply/divide?").lower()
print("You chose {}.".format(operation))    # for testing purposes

# step 2: ask for numbers, alert order matters for subtracting and dividing
if operation == "subtract" or operation == "divide":
    print("You chose {}.".format(operation))
    print("Please keep in mind that the order of your numbers matter.")
num1 = input("What is the first number?")
num2 = input("What is the second number?")
print("First number: {}".format(num1))  # for testing purposes
print("Second number: {}".format(num2)) # for testing purposes

# step 3: setup try/except for mathematical operation
try:
    #step 3a: immediately try to convert numbers input to float
    num1,num2 = float(num1),float(num2)
    # step 3b: perform operation and print result
    if operation == "add":
        result = num1 + num2
        print("{} + {} = {}".format(num1,num2,result))
    elif operation == "subtract":
        result = num1 - num2
        print("{} - {} = {}".format(num1,num2,result))
    elif operation == 'multiply':
        result = num1 * num2
        print("{} * {} = {}".format(num1,num2,result))
    elif operation == "divide":
        result = num1 / num2
        print("{} / {} = {}".format(num1,num2,result))
    else:
        # else will hit if they didn't chose an option correctly
        print("Sorry, but '{}' is not an option.".format(operation))
except:
    # step 3c: print error
    print("Error: Improper numbers used. Please try again.")
# Out:
# You chose subtract.
# You chose subtract.
# Please keep in mind that the order of your numbers matter.
# First number: 4
# Second number: 11
# 4.0 - 11.0 = -7.0

# %% [markdown]
# # Weekly challenges

# %%
try:
    age = int(input("What is your age?"))
    if age <= 12:
        print("Kid")
    elif age <= 19:
        print("Teenager")
    elif age <= 30:
        print("Young adult")
    elif age <= 64:
        print("Adult")
    elif age <= 150:
        print("Senior")
    else:
        print("Immortal")
except:
    print("Error: please type a number.")
# Out:
# Senior
