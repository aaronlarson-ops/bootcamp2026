# %% [markdown]
# # Creating and calling functions

# %%
# writing your first function
def printInfo():            # defines what the function does when called
    print("Name: John Smith")
    print("Age: 45")

printInfo()                 # calls the function to run
printInfo()                 # calls the function to run again

# %%
# performing a calculation in a function
def calc():
    x, y = 5, 10
    print(x+y)
calc()              # you will run the block of code within calc and output 15

# %% [markdown]
# # Monday exercises

# %%
# print name
def printName():
    print("Aaron")
printName()

# %%
# Pizza toppings
def pizza():
    print("Chicken")
    print("Barbeque sauce")
    print("Cheese")
    print("Beef")
    print("Meaty goodness")
pizza()
pizza()
pizza()

# %% [markdown]
# # Parameters

# %%
# passing a single parameter into a function
def printName(full_name):
    print("Your name is: {}.".format(full_name))
printName("John Smith")
printName("Amanda")

# %%
# passing multiple parameters into a function
def addNums(num1,num2):
    result = num1 + num2
    print("{} + {} = {}".format(num1,num2,result))
addNums(5,8)            # will output 13
addNums(3.5,5.5)        # will output 9.0

# %%
# using a function to square all information
numbers1 = [2,4,5,10]
numbers2 = [1,3,6]
def squares(nums):
    for num in nums:
        print(num**2)
squares(numbers1)
squares(numbers2)

# %%
# setting default parameter values
def calcArea(r, pi=3.14):
    area = pi * (r**2)
    print("Area: {}".format(area))
calcArea(2)         # assuming the radius is a value of 2

# %%
# creating optional parameters
def printName(first,last,middle=""):
    if middle:
        print("{} {} {}".format(first,middle,last))
    else:
        print("{} {}".format(first,last))
printName("John","Smith")
printName("John","Smith","Paul")        # will output with middle name

# %%
# explicitly assigning values to parameters by referencing the name
def addNums(num1,num2):
    print(num2)
    print(num1)
addNums(5,num2 = 2.5)

# %%
# using args parameter to take in a tuple of arbitrary values
def outputData(name,*args):
    print(type(args))
    for arg in args:
        print(arg)
outputData("John Smith",5,True,"Jess")

# %%
# using kwargs parameter to take in a dictionary of arbitrary values
def outputData(**kwargs):
    print(type(kwargs))
    print(kwargs["name"])
    print(kwargs["num"])
outputData(name = "John Smith",num = 5, b = True)

# %% [markdown]
# # Tuesday exercises

# %%
# user input
ans = input("Write a word")
def checkUpper(word):
    if word[0] == word[0].upper():
        print(True)
    else:
        print(False)
checkUpper(ans)

# %%
# no name
def printName(first_name="",last_name="", **kwargs):
    if first_name and last_name:
        print("{} {}".format(first_name,last_name))
    elif first_name and not last_name:
        print("{}, blank".format(first_name))
    elif last_name and not first_name:
        print("Blank, {}".format(last_name))
    else:
        print("No name passed in.")
printName("John","Smith")
printName("John")
printName(last_name = "Smith")
printName(b = 5)

# %% [markdown]
# # Return statement

# %%
# using return keyword to return the sum of two numbers
def addNums(num1, num2):
    return num1 + num2
num = addNums(5.5,4.5)      # saves returned value into num
print(num)
print(addNums(10,10))       # doesn't save returned value

# %%
# shorthand syntax using a ternary operator
def searchList(aList,el):
    return True if el in aList else False
result = searchList(["one",2,"three"],"one")  # checking if el("one") is in the list, result = True
print(result)

# %% [markdown]
# # Wednesday exercises

# %%
# full name
def combineName(first_name,last_name):
    return first_name + " " + last_name
print(combineName("Aaron","Larson"))

# %%
# user input
def userInput():
    return input("Write anything")
word = userInput()
print(word)

# %% [markdown]
# # Scope

# %%
# where global variables can be accessed
number = 5
def scopeTest():
    number += 1     # not accessible due to function level scope
scopeTest()

# %%
# accessing variables defined in a function
def scopeTest():
    word = "function"
    return word
value = scopeTest()
print(value)
# Out:
# function

# %%
# changing list item values by index
sports = ["baseball","football","hockey","basketball"]
def change(aList):
    aList[0] = "soccer"
print("Before altering: {}".format(sports))
change(sports)
print("After altering: {}".format(sports))
# Out:
# Before altering: ['baseball', 'football', 'hockey', 'basketball']
# After altering: ['soccer', 'football', 'hockey', 'basketball']

# %% [markdown]
# # Thursday exercises

# %%
# names
def changeValue(aList,name,index):
    aList[index] = name
names = ["Bob","Rich","Amanda"]
changeValue(names,"Bill",1)
print(names)
# Out:
# ['Bob', 'Bill', 'Amanda']

# %% [markdown]
# # Friday project: creating a shopping cart

# %%
# import necessary functions
from IPython.display import clear_output

# global list variable
cart = []

# create function to add items to cart
def addItem(item):
    clear_output()
    cart.append(item)
    print("{} has been added to the cart.".format(item))

# create function to remove items from cart
def removeItem(item):
    clear_output()
    try:
        cart.remove(item)
        print("{} has been removed from the cart.".format(item))
    except:
        print("Sorry, {} could not be removed from the cart.".format(item))

# create a function to show items in cart
def showCart():
    clear_output()
    if cart:
        print("Here is your cart:")
        for item in cart:
            print("- {}".format(item))
    else:
        print("Your cart is empty.")

# create function to clear items from cart
def clearCart():
    clear_output()
    cart.clear()
    print("Your cart is now empty.")

# create main function that loops until the user quits
def main():
    done = False
    while not done:
        ans = input("quit/add/remove/show/clear: ").lower
        # base case
        if ans == "quit":
            print("Thanks for using my program.")
            showCart()
            done = True
        elif ans == "add":
            item = input("What would you like to add?").title()
            addItem(item)
        elif ans == "remove":
            showCart()
            item = input("What item would you like to remove?").title()
            removeItem(item)
        elif ans == "show":
            showCart()
        elif ans == "clear":
            clearCart()
        else:
            print("Sorry, that was not an option.")
main()  # run the program
# Out:
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# Sorry, that was not an option.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 61
#      59         else:
#      60             print("Sorry, that was not an option.")
# ---> 61 main()  # run the program
#
# Cell In[45], line 42, in main()
#      40 done = False
#      41 while not done:
# ---> 42     ans = input("quit/add/remove/show/clear: ").lower
#      43     # base case
#      44     if ans == "quit":
#
# File c:\Users\alar0013\AppData\Local\anaconda3\envs\bootcamp2026\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File c:\Users\alar0013\AppData\Local\anaconda3\envs\bootcamp2026\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
